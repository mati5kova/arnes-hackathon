# %%
import geopandas as gpd

# %%
gdf_old = gpd.read_file("Data/kd_z_nevarnost.geojson")
gdf_rich = gpd.read_file("Data/kd_z_nevarnost_enriched_verified.geojson")

# %%
gdf_rich.columns
# Out:
# Index(['ESD', 'EID', 'IME', 'SINONIMI', 'OPIS', 'ZVRST', 'TIP', 'GESLA',
#        'DATACIJA', 'LOKACIJAOPIS', 'OBCINA', 'ZAVOD', 'USMERITVE', 'STATUS',
#        'PREDPIS', 'PREDPISHTTP', 'VELJAVNOST', 'FOTOAVTOR', 'FOTODATOTEKA',
#        'POVEZAVA1', 'SPOMENIK', 'OBCINAID', 'QR', 'X', 'Y', 'PHOTOURL',
#        'poplave_ocena', 'poplave', 'pozar', 'plazovi', 'regija', 'UE_UIME',
#        'potres', 'predominant_material', 'material_confidence',
#        'fire_danger_revised', 'flood_danger_revised',
#        'earthquake_danger_revised', 'landslide_danger_revised',
#        'danger_revision_reasoning', 'verification_status',
#        'verification_notes', 'sources', 'research_confidence', 'geometry'],
#       dtype='str')

# %%
gdf_check = gpd.GeoDataFrame()

# %%
gdf_check['poplave'] = (gdf_old['poplave'] - gdf_rich['flood_danger_revised']).abs()
gdf_check['pozar'] = (gdf_old['pozar'] - gdf_rich['fire_danger_revised']).abs()
gdf_check['potres'] = (gdf_old['potres'] - gdf_rich['earthquake_danger_revised']).abs()
gdf_check['plaz'] = (gdf_old['plazovi'] - gdf_rich['landslide_danger_revised']).abs()

# %%
gdf_komenda = gdf_rich[gdf_rich['OBCINA']=='KOMENDA']

# %%
gdf_komenda
# Out:
#          ESD      EID                                             IME  \
# 144      234  1-00234                              Komenda - Znamenje
# 207    30524  1-30524         Moste pri Komendi - Arheološko najdišče
# 1361   29742  1-29742  Gora pri Komendi - Domačija Gora pri Komendi 5
# 1847     231  1-00231                      Komenda - Cerkev sv. Petra
# 1848     232  1-00232                                  Komenda - Grad
# ...      ...      ...                                             ...
# 25363  30105  1-30105       Komenda - Arheološko območje Pod Stegnami
# 25384  30116  1-30116                 Komenda - Glavarjeva bolnišnica
# 25760  29213  1-29213        Suhadole - Arheološko najdišče Pri Pšati
# 25832  30284  1-30284                       Komenda - Glavarjeva hiša
# 26246  29556  1-29556            Breg pri Komendi - Klemenovo razpelo
#
#                                                 SINONIMI  \
# 144              Kužno znamenje, Kamnito gotsko znamenje
# 207                                                  NaN
# 1361                      Pri Koželj, Koželjeva domačija
# 1847                                             Komenda
# 1848   Šmidova graščina, Komenda malteškega viteškega...
# ...                                                  ...
# 25363                                                NaN
# 25384               Glavarjev špital, Glavarjeva bolnica
# 25760                                                NaN
# 25832  Beneficiatna hiša, Glavarjeva beneficiatura, G...
# 26246                                 Klemenovo znamenje
#
#                                                     OPIS  \
# 144    Gotsko stebrasto znamenje sestavljajo iz pešče...
# 207    Sledovi prazgodovinske in rimskodobne poselitv...
# 1361   Okrog dvorišča so nanizani podkletena zidana h...
# 1847   Baročna cerkev s kvalitetno opremo in predelav...
# 1848   Nadstropen štirtrakten grad z notranjim dvoriš...
# ...                                                  ...
# 25363  Območje povečanega arheološkega potenciala gle...
# 25384  Nadstropna stavba z devetosno glavno fasado, o...
# 25760  Sledovi rimskodobne poselitve (najdbe gradbene...
# 25832  Peter Pavel Glavar je 1752 dal zgraditi nadstr...
# 26246  Lesen križ s sedlasto oblikovano pločevinasto ...
#
#                             ZVRST                         TIP  \
# 144    spominski objekti in kraji  sakralna stavbna dediščina
# 207           arheološka najdišča        arheološka dediščina
# 1361                       stavbe   profana stavbna dediščina
# 1847                       stavbe  sakralna stavbna dediščina
# 1848                       stavbe   profana stavbna dediščina
# ...                           ...                         ...
# 25363         arheološka najdišča        arheološka dediščina
# 25384                      stavbe   profana stavbna dediščina
# 25760         arheološka najdišča        arheološka dediščina
# 25832                      stavbe   profana stavbna dediščina
# 26246  spominski objekti in kraji  sakralna stavbna dediščina
#
#                                                    GESLA  \
# 144                                     stebrno znamenje
# 207                                            naselbina
# 1361   domačija na vogel, kmečka hiša, gospodarsko po...
# 1847                         župnijska cerkev, sv. Peter
# 1848   grad, hlev, gospodarsko poslopje, vodnjak, lip...
# ...                                                  ...
# 25363                                 arheološko območje
# 25384                       špital, šola, spominska soba
# 25760                                          naselbina
# 25832  beneficiatna hiša, spominska soba, spominska p...
# 26246                                     razpelo, drevo
#
#                                                 DATACIJA  \
# 144    prva četrtina 16. stol.,  1510, zadnja četrtin...
# 207                            prazgodovina, rimska doba
# 1361                      prva četrtina 19. stol.,  1818
# 1847   druga četrtina 18. stol.,  1727, druga četrtin...
# 1848   13. stol., zadnja četrtina 15. stol.,  1499, s...
# ...                                                  ...
# 25363                                        rimska doba
# 25384  prva četrtina 19. stol.,  1804, druga četrtina...
# 25760                                        rimska doba
# 25832  sredina 18. stol.,  1752,  1766, druga polovic...
# 26246  zadnja četrtina 19. stol.,  1884, prelom 20. s...
#
#                                             LOKACIJAOPIS  ...  \
# 144    Znamenje je postavljeno na rob brega v jugovzh...  ...
# 207    Arheološko najdišče je na njivskih površinah j...  ...
# 1361   Gora pri Komendi 5. Koželjeva domačija stoji o...  ...
# 1847   Glavarjeva 110. Na koncu vasi, severno nad pok...  ...
# 1848   Glavarjeva cesta 114. Grad in poslopja stojijo...  ...
# ...                                                  ...  ...
# 25363  Arheološko območje je na njivi zahodno od jedr...  ...
# 25384  Glavarjeva cesta 104 in 106. Glavarjev špital ...  ...
# 25760  Arheološko najdišče je na njivah in travnikih ...  ...
# 25832  Glavarjeva cesta 77. Glavarjeva hiša stoji sre...  ...
# 26246  Razpelo stoji severno ob cesti Komenda-Breg pr...  ...
#
#       fire_danger_revised flood_danger_revised earthquake_danger_revised  \
# 144                   3.8                  2.1                       0.3
# 207                   3.8                  2.0                       0.2
# 1361                  4.4                  2.0                       0.6
# 1847                  4.0                  2.0                       0.8
# 1848                  4.0                  2.0                       0.8
# ...                   ...                  ...                       ...
# 25363                 3.8                  3.0                       0.2
# 25384                 4.0                  2.0                       0.7
# 25760                 3.8                  2.0                       0.2
# 25832                 3.8                  2.0                       0.4
# 26246                 3.8                  2.1                       0.3
#
#       landslide_danger_revised  \
# 144                        1.2
# 207                        1.0
# 1361                       1.2
# 1847                       1.0
# 1848                       1.2
# ...                        ...
# 25363                      1.0
# 25384                      1.0
# 25760                      1.0
# 25832                      1.2
# 26246                      1.3
#
#                                danger_revision_reasoning verification_status  \
# 144    Official register record supports stone/marble...            verified
# 207    Official register record supports earthworks a...  partially_verified
# 1361   Official register record supports mixed masonr...            verified
# 1847   Official register record supports stone masonr...  partially_verified
# 1848   Official register record supports stone masonr...  partially_verified
# ...                                                  ...                 ...
# 25363  Official register record supports earthworks a...  partially_verified
# 25384  Official register record supports stone masonr...            verified
# 25760  Official register record supports earthworks a...  partially_verified
# 25832  Official register record supports stone/marble...            verified
# 26246  Official register record supports stone/marble...            verified
#
#                                       verification_notes  \
# 144    Identity anchored by RNPD/eVRD-style official ...
# 207    Identity anchored by official register metadat...
# 1361   Identity anchored by RNPD/eVRD-style official ...
# 1847   Identity anchored by official register metadat...
# 1848   Identity anchored by official register metadat...
# ...                                                  ...
# 25363  Identity anchored by official register metadat...
# 25384  Identity anchored by RNPD/eVRD-style official ...
# 25760  Identity anchored by official register metadat...
# 25832  Identity anchored by RNPD/eVRD-style official ...
# 26246  Identity anchored by RNPD/eVRD-style official ...
#
#                                                  sources research_confidence  \
# 144    [https://eid.gov.si/S/234, RNPD description an...                 0.8
# 207    [https://eid.gov.si/S/30524, RNPD description ...                 0.7
# 1361   [https://eid.gov.si/S/29742, RNPD description ...                 0.8
# 1847   [https://eid.gov.si/S/231, RNPD description an...                 0.7
# 1848   [https://eid.gov.si/S/232, RNPD description an...                 0.7
# ...                                                  ...                 ...
# 25363  [https://eid.gov.si/S/30105, RNPD description ...                 0.7
# 25384  [https://eid.gov.si/S/30116, RNPD description ...                 0.8
# 25760  [https://eid.gov.si/S/29213, RNPD description ...                 0.7
# 25832  [https://eid.gov.si/S/30284, RNPD description ...                 0.8
# 26246  [https://eid.gov.si/S/29556, RNPD description ...                 0.8
#
#                         geometry
# 144     POINT (14.5391 46.20779)
# 207    POINT (14.54198 46.19344)
# 1361   POINT (14.54884 46.20697)
# 1847   POINT (14.53945 46.20873)
# 1848   POINT (14.53927 46.20907)
# ...                          ...
# 25363  POINT (14.51896 46.20193)
# 25384  POINT (14.53916 46.20714)
# 25760  POINT (14.54979 46.18244)
# 25832  POINT (14.53884 46.20738)
# 26246  POINT (14.52408 46.21047)
#
# [101 rows x 45 columns]
